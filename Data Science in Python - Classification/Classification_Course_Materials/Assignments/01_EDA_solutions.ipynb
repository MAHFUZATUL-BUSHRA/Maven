# %% [markdown]
# ## Assignment 1: EDA
#
# 1. Read in `income.csv`
# 2. Convert the target, `SalStat` into a binary numeric variable called `target`, and build a bar chart that plots the frequency of each value.
# 3. Explore the numeric features using histograms or boxplots.
# 4. Explore the categorical features using bar charts.
# 5. Consider writing functions for steps 3 and 4.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
#    age       JobType         EdType        maritalstatus       occupation  \
# 0   45       Private        HS-grad             Divorced     Adm-clerical
# 1   24   Federal-gov        HS-grad        Never-married     Armed-Forces
# 2   44       Private   Some-college   Married-civ-spouse   Prof-specialty
# 3   27       Private            9th        Never-married     Craft-repair
# 4   20       Private   Some-college        Never-married            Sales
#
#       relationship    race   gender  capitalgain  capitalloss  hoursperweek  \
# 0    Not-in-family   White   Female            0            0            28
# 1        Own-child   White     Male            0            0            40
# 2          Husband   White     Male            0            0            40
# 3   Other-relative   White     Male            0            0            40
# 4    Not-in-family   White     Male            0            0            35
#
#     nativecountry                        SalStat
# 0   United-States   less than or equal to 50,000
# 1   United-States   less than or equal to 50,000
# 2   United-States            greater than 50,000
# 3          Mexico   less than or equal to 50,000
# 4   United-States   less than or equal to 50,000

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31978 entries, 0 to 31977
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            31978 non-null  int64
#  1   JobType        31978 non-null  object
#  2   EdType         31978 non-null  object
#  3   maritalstatus  31978 non-null  object
#  4   occupation     31978 non-null  object
#  5   relationship   31978 non-null  object
#  6   race           31978 non-null  object
#  7   gender         31978 non-null  object
#  8   capitalgain    31978 non-null  int64
#  9   capitalloss    31978 non-null  int64
#  10  hoursperweek   31978 non-null  int64
#  11  nativecountry  31978 non-null  object
#  12  SalStat        31978 non-null  object
# dtypes: int64(4), object(9)
# memory usage: 3.2+ MB

# %%
income["target"] = np.where(income["SalStat"] == ' less than or equal to 50,000', 0, 1)

income["target"].value_counts(normalize=True).plot.bar()
# Out:
# <Axes: xlabel='target'>

# %%
def num_box_plotter(data):
    for column in data.select_dtypes("number"):
        sns.boxplot(data[column]).set(ylabel=column)
        plt.show()

# %%
num_box_plotter(income)

# %%
def cat_bar_plotter(data, normalize=False):

    for column in data.select_dtypes("object"):
        data[column].value_counts(normalize=normalize).plot.bar()  
        plt.show()

# %%
cat_bar_plotter(income, normalize=True)

# %%
sns.scatterplot(loan_df, x="loan_amount", y="Status");b

# %%
sns.scatterplot(loan_df, x="loan_amount", y="property_value")

# %%
loan_df.corr(numeric_only=True)

# %%
sns.heatmap(
    loan_df.corr(numeric_only=True),
    vmin=-1,
    vmax=1,
    cmap="coolwarm"
)

# %%
def num_plotter(data, target):
    for col in data.select_dtypes(["int", "float"]):
        sns.boxplot(data=data, x=col, hue=target, stat="percent", kde=True, bins=20
                   )
        plt.show()
        
num_plotter(income, "SalStat")

# %%
income["target"] = np.where(income["SalStat"] == " less than or equal to 50,000", 0, 1)

# %%
def cat_plotter(data, target):
    for col in data.select_dtypes(["object"]).columns:
        sns.barplot(
            data=(
                data
                .groupby(col, as_index=False)
                .agg({"target": "mean"})
                .sort_values(by="target", ascending=False)
                 ), 
            x=col, 
            y=target)
        plt.xticks(rotation=45)
        plt.show()
        
cat_plotter(income, "target")

# %% [markdown]
# ## Assignment 2: Data Prep
#
# 1. Create Dummy Variables for the categorical features - check value counts to determine if any categories need to be grouped.
# 2. Split of 20% of the data to hold out as a test set, and use the rest for training. There should be 4 datasets, one each for the features and target for the train and test sets.

# %%
def value_counter(dataframe):
    for col in dataframe.select_dtypes(["object"]).columns:
        print(dataframe[col].value_counts())
        
        
value_counter(income)
# Out:
#  Private             22286
#  Self-emp-not-inc     2499
#  Local-gov            2067
#  ?                    1809
#  State-gov            1279
#  Self-emp-inc         1074
#  Federal-gov           943
#  Without-pay            14
#  Never-worked            7
# Name: JobType, dtype: int64
#  HS-grad         10368
#  Some-college     7187
#  Bachelors        5210
#  Masters          1674
#  Assoc-voc        1366
#  11th             1167
#  Assoc-acdm       1055
#  10th              921
#  7th-8th           627
#  Prof-school       559
#  9th               506
#  12th              417
#  Doctorate         390
#  5th-6th           318
#  1st-4th           163
#  Preschool          50
# Name: EdType, dtype: int64
#  Married-civ-spouse       14692
#  Never-married            10488
#  Divorced                  4394
#  Separated                 1005
#  Widowed                    979
#  Married-spouse-absent      397
#  Married-AF-spouse           23
# Name: maritalstatus, dtype: int64
#  Prof-specialty       4038
#  Craft-repair         4030
#  Exec-managerial      3992
#  Adm-clerical         3721
#  Sales                3584
#  Other-service        3212
#  Machine-op-inspct    1966
#  ?                    1816
#  Transport-moving     1572
#  Handlers-cleaners    1350
#  Farming-fishing       989
#  Tech-support          912
#  Protective-serv       644
#  Priv-house-serv       143
#  Armed-Forces            9
# Name: occupation, dtype: int64
#  Husband           12947
#  Not-in-family      8156
#  Own-child          5005
#  Unmarried          3384
#  Wife               1534
#  Other-relative      952
# Name: relationship, dtype: int64
#  White                 27430
#  Black                  3028
#  Asian-Pac-Islander      956
#  Amer-Indian-Eskimo      311
#  Other                   253
# Name: race, dtype: int64
#  Male      21370
#  Female    10608
# Name: gender, dtype: int64
#  United-States                 29170
#  Mexico                          643
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Trinadad&Tobago                  19
#  Cambodia                         19
#  Thailand                         18
#  Laos                             18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: nativecountry, dtype: int64
#  less than or equal to 50,000    24283
#  greater than 50,000              7695
# Name: SalStat, dtype: int64

# %%
income["nativecountry"].unique()
# Out:
# array([' United-States', ' Mexico', ' Portugal', ' El-Salvador',
#        ' Poland', ' France', ' Puerto-Rico', ' Canada', ' Cuba',
#        ' Taiwan', ' Philippines', ' South', ' Dominican-Republic',
#        ' Jamaica', ' Honduras', ' Haiti', ' Germany', ' Guatemala',
#        ' England', ' Italy', ' China', ' India', ' Japan', ' Yugoslavia',
#        ' Iran', ' Thailand', ' Peru', ' Outlying-US(Guam-USVI-etc)',
#        ' Scotland', ' Trinadad&Tobago', ' Greece', ' Nicaragua',
#        ' Cambodia', ' Vietnam', ' Hong', ' Columbia', ' Ireland',
#        ' Ecuador', ' Laos', ' Hungary', ' Holand-Netherlands'],
#       dtype=object)

# %%
# map holland to germany
# map armed forces
# group without-pay and never-worked

income = income.assign(
    nativecountry = income["nativecountry"].replace({" Holand-Netherlands": " Germany"}),
    occupation = income["occupation"].replace({" Armed-Forces": " ?"}),
    JobType = income["JobType"].replace({" Never-worked": " Without-pay"}),
)

value_counter(income)
# Out:
#  Private             22286
#  Self-emp-not-inc     2499
#  Local-gov            2067
#  ?                    1809
#  State-gov            1279
#  Self-emp-inc         1074
#  Federal-gov           943
#  Without-pay            21
# Name: JobType, dtype: int64
#  HS-grad         10368
#  Some-college     7187
#  Bachelors        5210
#  Masters          1674
#  Assoc-voc        1366
#  11th             1167
#  Assoc-acdm       1055
#  10th              921
#  7th-8th           627
#  Prof-school       559
#  9th               506
#  12th              417
#  Doctorate         390
#  5th-6th           318
#  1st-4th           163
#  Preschool          50
# Name: EdType, dtype: int64
#  Married-civ-spouse       14692
#  Never-married            10488
#  Divorced                  4394
#  Separated                 1005
#  Widowed                    979
#  Married-spouse-absent      397
#  Married-AF-spouse           23
# Name: maritalstatus, dtype: int64
#  Prof-specialty       4038
#  Craft-repair         4030
#  Exec-managerial      3992
#  Adm-clerical         3721
#  Sales                3584
#  Other-service        3212
#  Machine-op-inspct    1966
#  ?                    1825
#  Transport-moving     1572
#  Handlers-cleaners    1350
#  Farming-fishing       989
#  Tech-support          912
#  Protective-serv       644
#  Priv-house-serv       143
# Name: occupation, dtype: int64
#  Husband           12947
#  Not-in-family      8156
#  Own-child          5005
#  Unmarried          3384
#  Wife               1534
#  Other-relative      952
# Name: relationship, dtype: int64
#  White                 27430
#  Black                  3028
#  Asian-Pac-Islander      956
#  Amer-Indian-Eskimo      311
#  Other                   253
# Name: race, dtype: int64
#  Male      21370
#  Female    10608
# Name: gender, dtype: int64
#  United-States                 29170
#  Mexico                          643
#  Philippines                     198
#  Germany                         138
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  Greece                           29
#  France                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Trinadad&Tobago                  19
#  Cambodia                         19
#  Thailand                         18
#  Laos                             18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
# Name: nativecountry, dtype: int64
#  less than or equal to 50,000    24283
#  greater than 50,000              7695
# Name: SalStat, dtype: int64

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31978 entries, 0 to 31977
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            31978 non-null  int64
#  1   JobType        31978 non-null  object
#  2   EdType         31978 non-null  object
#  3   maritalstatus  31978 non-null  object
#  4   occupation     31978 non-null  object
#  5   relationship   31978 non-null  object
#  6   race           31978 non-null  object
#  7   gender         31978 non-null  object
#  8   capitalgain    31978 non-null  int64
#  9   capitalloss    31978 non-null  int64
#  10  hoursperweek   31978 non-null  int64
#  11  nativecountry  31978 non-null  object
#  12  SalStat        31978 non-null  object
#  13  target         31978 non-null  int64
# dtypes: int64(5), object(9)
# memory usage: 3.4+ MB

# %%
income = pd.get_dummies(income, drop_first=True)

# %%
def income_model_prep(data):
    from sklearn.model_selection import train_test_split
    data = pd.get_dummies(
        data.assign(
            target = np.where(data["SalStat"] == " less than or equal to 50,000", 0, 1),
            nativecountry = data["nativecountry"].replace({" Holand-Netherlands": " Germany"}),
            occupation = data["occupation"].replace({" Armed-Forces": " ?"}),
            JobType = data["JobType"].replace({" Never-worked": " Without-pay"}),
        ).drop("SalStat", axis=1), 
        drop_first=True
    )
    X = data.drop("target", axis=1)
    y = data["target"]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    return X_train, X_test, y_train, y_test

# %%
income = pd.read_csv("../Data/income.csv")

X_train, X_test, y_train, y_test = income_model_prep(income)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25582 entries, 2337 to 2732
# Data columns (total 94 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   age                                        25582 non-null  int64
#  1   capitalgain                                25582 non-null  int64
#  2   capitalloss                                25582 non-null  int64
#  3   hoursperweek                               25582 non-null  int64
#  4   JobType_ Federal-gov                       25582 non-null  uint8
#  5   JobType_ Local-gov                         25582 non-null  uint8
#  6   JobType_ Private                           25582 non-null  uint8
#  7   JobType_ Self-emp-inc                      25582 non-null  uint8
#  8   JobType_ Self-emp-not-inc                  25582 non-null  uint8
#  9   JobType_ State-gov                         25582 non-null  uint8
#  10  JobType_ Without-pay                       25582 non-null  uint8
#  11  EdType_ 11th                               25582 non-null  uint8
#  12  EdType_ 12th                               25582 non-null  uint8
#  13  EdType_ 1st-4th                            25582 non-null  uint8
#  14  EdType_ 5th-6th                            25582 non-null  uint8
#  15  EdType_ 7th-8th                            25582 non-null  uint8
#  16  EdType_ 9th                                25582 non-null  uint8
#  17  EdType_ Assoc-acdm                         25582 non-null  uint8
#  18  EdType_ Assoc-voc                          25582 non-null  uint8
#  19  EdType_ Bachelors                          25582 non-null  uint8
#  20  EdType_ Doctorate                          25582 non-null  uint8
#  21  EdType_ HS-grad                            25582 non-null  uint8
#  22  EdType_ Masters                            25582 non-null  uint8
#  23  EdType_ Preschool                          25582 non-null  uint8
#  24  EdType_ Prof-school                        25582 non-null  uint8
#  25  EdType_ Some-college                       25582 non-null  uint8
#  26  maritalstatus_ Married-AF-spouse           25582 non-null  uint8
#  27  maritalstatus_ Married-civ-spouse          25582 non-null  uint8
#  28  maritalstatus_ Married-spouse-absent       25582 non-null  uint8
#  29  maritalstatus_ Never-married               25582 non-null  uint8
#  30  maritalstatus_ Separated                   25582 non-null  uint8
#  31  maritalstatus_ Widowed                     25582 non-null  uint8
#  32  occupation_ Adm-clerical                   25582 non-null  uint8
#  33  occupation_ Craft-repair                   25582 non-null  uint8
#  34  occupation_ Exec-managerial                25582 non-null  uint8
#  35  occupation_ Farming-fishing                25582 non-null  uint8
#  36  occupation_ Handlers-cleaners              25582 non-null  uint8
#  37  occupation_ Machine-op-inspct              25582 non-null  uint8
#  38  occupation_ Other-service                  25582 non-null  uint8
#  39  occupation_ Priv-house-serv                25582 non-null  uint8
#  40  occupation_ Prof-specialty                 25582 non-null  uint8
#  41  occupation_ Protective-serv                25582 non-null  uint8
#  42  occupation_ Sales                          25582 non-null  uint8
#  43  occupation_ Tech-support                   25582 non-null  uint8
#  44  occupation_ Transport-moving               25582 non-null  uint8
#  45  relationship_ Not-in-family                25582 non-null  uint8
#  46  relationship_ Other-relative               25582 non-null  uint8
#  47  relationship_ Own-child                    25582 non-null  uint8
#  48  relationship_ Unmarried                    25582 non-null  uint8
#  49  relationship_ Wife                         25582 non-null  uint8
#  50  race_ Asian-Pac-Islander                   25582 non-null  uint8
#  51  race_ Black                                25582 non-null  uint8
#  52  race_ Other                                25582 non-null  uint8
#  53  race_ White                                25582 non-null  uint8
#  54  gender_ Male                               25582 non-null  uint8
#  55  nativecountry_ Canada                      25582 non-null  uint8
#  56  nativecountry_ China                       25582 non-null  uint8
#  57  nativecountry_ Columbia                    25582 non-null  uint8
#  58  nativecountry_ Cuba                        25582 non-null  uint8
#  59  nativecountry_ Dominican-Republic          25582 non-null  uint8
#  60  nativecountry_ Ecuador                     25582 non-null  uint8
#  61  nativecountry_ El-Salvador                 25582 non-null  uint8
#  62  nativecountry_ England                     25582 non-null  uint8
#  63  nativecountry_ France                      25582 non-null  uint8
#  64  nativecountry_ Germany                     25582 non-null  uint8
#  65  nativecountry_ Greece                      25582 non-null  uint8
#  66  nativecountry_ Guatemala                   25582 non-null  uint8
#  67  nativecountry_ Haiti                       25582 non-null  uint8
#  68  nativecountry_ Honduras                    25582 non-null  uint8
#  69  nativecountry_ Hong                        25582 non-null  uint8
#  70  nativecountry_ Hungary                     25582 non-null  uint8
#  71  nativecountry_ India                       25582 non-null  uint8
#  72  nativecountry_ Iran                        25582 non-null  uint8
#  73  nativecountry_ Ireland                     25582 non-null  uint8
#  74  nativecountry_ Italy                       25582 non-null  uint8
#  75  nativecountry_ Jamaica                     25582 non-null  uint8
#  76  nativecountry_ Japan                       25582 non-null  uint8
#  77  nativecountry_ Laos                        25582 non-null  uint8
#  78  nativecountry_ Mexico                      25582 non-null  uint8
#  79  nativecountry_ Nicaragua                   25582 non-null  uint8
#  80  nativecountry_ Outlying-US(Guam-USVI-etc)  25582 non-null  uint8
#  81  nativecountry_ Peru                        25582 non-null  uint8
#  82  nativecountry_ Philippines                 25582 non-null  uint8
#  83  nativecountry_ Poland                      25582 non-null  uint8
#  84  nativecountry_ Portugal                    25582 non-null  uint8
#  85  nativecountry_ Puerto-Rico                 25582 non-null  uint8
#  86  nativecountry_ Scotland                    25582 non-null  uint8
#  87  nativecountry_ South                       25582 non-null  uint8
#  88  nativecountry_ Taiwan                      25582 non-null  uint8
#  89  nativecountry_ Thailand                    25582 non-null  uint8
#  90  nativecountry_ Trinadad&Tobago             25582 non-null  uint8
#  91  nativecountry_ United-States               25582 non-null  uint8
#  92  nativecountry_ Vietnam                     25582 non-null  uint8
#  93  nativecountry_ Yugoslavia                  25582 non-null  uint8
# dtypes: int64(4), uint8(90)
# memory usage: 3.2 MB
